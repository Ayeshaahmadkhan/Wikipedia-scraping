# %%
# !pip install wikipedia-api

# %%
import wikipediaapi

# Custom user-agent string
user_agent = "MyPhysicsProject/1.0"

# Create a Wikipedia API object with the custom user-agent
wiki_wiki = wikipediaapi.Wikipedia(language='en', user_agent=user_agent)

# Function to check if a Wikipedia page exists
def check_wikipedia_page_exists(page_title):
    page = wiki_wiki.page(page_title)
    return page.exists()

# List of page titles for the topics
topics = [
    "Physical quantity", "International System of Units", "Errors and residuals in statistics", "Uncertainty",
    "Accuracy and precision", "Significant figures", "Vector (mathematics and physics)", "Euclidean vector",
    "Vector space", "Vector addition", "Dot product", "Cross product", "Torque", "Equilibrium of rigid bodies",
    "Displacement (vector)", "Velocity", "Acceleration", "Newton's laws of motion", "Momentum", "Conservation of momentum",
    "Elastic collision", "Inelastic collision", "Work (physics)", "Gravitational field", "Power (physics)", "Energy",
    "Kinetic energy", "Potential energy", "Conservation of energy", "Renewable energy", "Alternative energy",
    "Angular displacement", "Angular velocity", "Angular acceleration", "Centripetal force", "Moment of inertia",
    "Angular momentum", "Conservation of angular momentum", "Rotational kinetic energy", "Viscosity", "Stokes' law",
    "Terminal velocity", "Fluid dynamics", "Continuity equation", "Bernoulli's principle", "Simple harmonic motion",
    "Uniform circular motion", "Pendulum", "Conservation of mechanical energy", "Resonance","Simple harmonic motion", "Wave",
    "Superposition principle", "Harmonic oscillator", "Oscillation", "Airy wave theory", "Electromagnetic radiation",
    "Wave interference", "Reflection coefficient", "Standing wave", "Diffraction", "Wave–particle duality", "Aspheric lens",
    "Angular resolution", "Laws of thermodynamics", "Heat transfer", "Thermal expansion", "Electric field", "RC circuit",
    "Electronic circuit", "Electric power", "Power station", "Magnetic field", "Quantum entanglement", "Thermodynamics",
    "Electrostatics", "Electric current", "Magnetic field", "Electromagnetic induction", "Alternating current", "Electromagnetic radiation",
    "Optics", "Wave–particle duality", "Atom "," Atomic nucleus", "Semiconductor device", "Communication system", "Classical mechanics",
    "Work (physics)","Energy","Power (physics)", "Rotation around a fixed axis", "Gravitation", "Solid mechanics", "Fluid mechanics",
    "Thermal physics", "Thermodynamics", "Kinetic theory of gases", "Oscillation", "Wave", "Electric charge", "Electric field",
    "Geometrical optics"," Optical instrument", "Nuclear physics", "Modern physics","Gauss's law", "Electric potential",
    "Electric potential energy", "Electric current", "Kirchhoff's circuit laws", "Electrical resistivity and conductivity",
    "Internal resistance", "Electromagnetism", "Ampère's circuital law", "Solenoid", "Magnetic field", "Lorentz force", "Galvanometer",
    "Electromagnetic induction", "Lenz's law", "AC motor", "Electric generator", "Transformer", "Alternating current", "Inductor",
    "Capacitor", "RLC circuit", "Electrical impedance", "Solid-state physics", "Stress-strain curve", "Electronic band structure",
    "Superconductivity", "Electronics", "P–n junction", "Transistor", "Rectifier", "History of physics", "Special relativity",
    "Photoelectric effect", "Compton scattering", "Uncertainty principle", "De Broglie hypothesis", "Atomic spectroscopy", "X-ray",
    "Laser", "Nuclear physics", "Mass spectrometer", "Half-life", "Radiation detector"
]


# Check if the pages exist
for topic in topics:
    exists = check_wikipedia_page_exists(topic)
    print(f"Page '{topic}' exists: {exists}")
# Out:
# Page 'Physical quantity' exists: True
# Page 'International System of Units' exists: True
# Page 'Errors and residuals in statistics' exists: True
# Page 'Uncertainty' exists: True
# Page 'Accuracy and precision' exists: True
# Page 'Significant figures' exists: True
# Page 'Vector (mathematics and physics)' exists: True
# Page 'Euclidean vector' exists: True
# Page 'Vector space' exists: True
# Page 'Vector addition' exists: True
# Page 'Dot product' exists: True
# Page 'Cross product' exists: True
# Page 'Torque' exists: True
# Page 'Equilibrium of rigid bodies' exists: False
# Page 'Displacement (vector)' exists: True
# Page 'Velocity' exists: True
# Page 'Acceleration' exists: True
# Page 'Newton's laws of motion' exists: True
# Page 'Momentum' exists: True
# Page 'Conservation of momentum' exists: True
# Page 'Elastic collision' exists: True
# Page 'Inelastic collision' exists: True
# Page 'Work (physics)' exists: True
# Page 'Gravitational field' exists: True
# ...

# %%
# After correcting false name
topics = [
    "Physical quantity", "International System of Units", "Errors and residuals in statistics", "Uncertainty",
    "Accuracy and precision", "Significant figures", "Vector (mathematics and physics)", "Euclidean vector",
    "Vector space", "Vector addition", "Dot product", "Cross product", "Torque", "Rigid body dynamics",
    "Displacement (vector)", "Velocity", "Acceleration", "Newton's laws of motion", "Momentum", "Conservation of momentum",
    "Elastic collision", "Inelastic collision", "Work (physics)", "Gravitational field", "Power (physics)", "Energy",
    "Kinetic energy", "Potential energy", "Conservation of energy", "Renewable energy", "Alternative energy",
    "Angular displacement", "Angular velocity", "Angular acceleration", "Centripetal force", "Moment of inertia",
    "Angular momentum", "Conservation of angular momentum", "Rotational kinetic energy", "Viscosity", "Stokes' law",
    "Terminal velocity", "Fluid dynamics", "Continuity equation", "Bernoulli's principle", "Simple harmonic motion",
    "Uniform circular motion", "Pendulum", "Conservation of mechanical energy", "Resonance","Simple harmonic motion", "Wave",
    "Superposition principle", "Harmonic oscillator", "Oscillation", "Airy wave theory", "Electromagnetic radiation",
    "Wave interference", "Reflection coefficient", "Standing wave", "Diffraction", "Wave–particle duality", "Aspheric lens",
    "Angular resolution", "Laws of thermodynamics", "Heat transfer", "Thermal expansion", "Electric field", "RC circuit",
    "Electronic circuit", "Electric power", "Power station", "Magnetic field", "Quantum entanglement", "Thermodynamics",
    "Electrostatics", "Electric current", "Magnetic field", "Electromagnetic induction", "Alternating current", "Electromagnetic radiation",
    "Optics", "Wave–particle duality", "Atom "," Atomic nucleus", "Semiconductor device", "Communication system", "Classical mechanics",
    "Work (physics)","Energy","Power (physics)", "Rotation around a fixed axis", "Gravitation", "Solid mechanics", "Fluid mechanics",
    "Thermal physics", "Thermodynamics", "Kinetic theory of gases", "Oscillation", "Wave", "Electric charge", "Electric field",
    "Geometrical optics"," Optical instrument", "Nuclear physics", "Modern physics","Gauss's law", "Electric potential",
    "Electric potential energy", "Electric current", "Kirchhoff's circuit laws", "Electrical resistivity and conductivity",
    "Internal resistance", "Electromagnetism", "Ampère's circuital law", "Solenoid", "Magnetic field", "Lorentz force", "Galvanometer",
    "Electromagnetic induction", "Lenz's law", "AC motor", "Electric generator", "Transformer", "Alternating current", "Inductor",
    "Capacitor", "RLC circuit", "Electrical impedance", "Solid-state physics", "Stress-strain curve", "Electronic band structure",
    "Superconductivity", "Electronics", "P–n junction", "Transistor", "Rectifier", "History of physics", "Special relativity",
    "Photoelectric effect", "Compton scattering", "Uncertainty principle", "De Broglie hypothesis", "Atomic spectroscopy", "X-ray",
    "Laser", "Nuclear physics", "Mass spectrometer", "Half-life", "Radiation detector"
]


# Check if the pages exist
for topic in topics:
    exists = check_wikipedia_page_exists(topic)
    print(f"Page '{topic}' exists: {exists}")

# Count the number of topics
num_topics = len(topics)
print(f"Total number of topics: {num_topics}")
# Out:
# Page 'Physical quantity' exists: True
# Page 'International System of Units' exists: True
# Page 'Errors and residuals in statistics' exists: True
# Page 'Uncertainty' exists: True
# Page 'Accuracy and precision' exists: True
# Page 'Significant figures' exists: True
# Page 'Vector (mathematics and physics)' exists: True
# Page 'Euclidean vector' exists: True
# Page 'Vector space' exists: True
# Page 'Vector addition' exists: True
# Page 'Dot product' exists: True
# Page 'Cross product' exists: True
# Page 'Torque' exists: True
# Page 'Rigid body dynamics' exists: True
# Page 'Displacement (vector)' exists: True
# Page 'Velocity' exists: True
# Page 'Acceleration' exists: True
# Page 'Newton's laws of motion' exists: True
# Page 'Momentum' exists: True
# Page 'Conservation of momentum' exists: True
# Page 'Elastic collision' exists: True
# Page 'Inelastic collision' exists: True
# Page 'Work (physics)' exists: True
# Page 'Gravitational field' exists: True
# ...

# %%
import wikipediaapi
import pandas as pd
import re
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

# Function to fetch and clean Wikipedia content
def fetch_clean_wikipedia_content(topic):
    page = wiki_wiki.page(topic)
    if page.exists():
        content = page.text
        # Remove special characters and extra whitespaces
        content = re.sub(r'\[.*?\]', '', content)  # Remove citations
        content = re.sub(r'\s+', ' ', content)  # Remove extra whitespaces
        content = re.sub(r'https?:\/\/\S+', '', content)  # Remove URLs
        # Remove special characters
        content = re.sub(r'[^a-zA-Z0-9\s]', '', content)

        return content, page.fullurl

    return None

# Fetch and clean content for each topic
data = {'Topic': [], 'Content': [], 'URL': [], 'Type': [], 'Vocabulary Size': [], 'Word Count': []}

for topic in topics:
    content_and_url = fetch_clean_wikipedia_content(topic)
    if content_and_url is not None:
        content, url = content_and_url
        # Tokenize the content to get word count and vocabulary size
        tokens = word_tokenize(content.lower())
        tokens = [word for word in tokens if word.isalpha()]
        vocab_size = len(set(tokens))
        word_count = len(tokens)

        # Determine the type based on the length of the content
        content_type = 'Short' if word_count <= 1000 else 'Long'

        data['Topic'].append(topic)
        data['Content'].append(content)
        data['URL'].append(url)
        data['Type'].append(content_type)
        data['Vocabulary Size'].append(vocab_size)
        data['Word Count'].append(word_count)
    else:
        print(f"Unable to fetch content for topic: {topic}")

# Create a DataFrame
df = pd.DataFrame(data)

# Save DataFrame to a CSV file
df.to_csv('corpus.csv', index=False)

# Reset display options to default
pd.reset_option('display.max_colwidth')

# Display the DataFrame
display(df)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                   Topic  \
# 0                     Physical quantity
# 1         International System of Units
# 2    Errors and residuals in statistics
# 3                           Uncertainty
# 4                Accuracy and precision
# ..                                  ...
# 145                               Laser
# 146                     Nuclear physics
# 147                   Mass spectrometer
# 148                           Half-life
# 149                  Radiation detector
#
#                                                Content  \
# 0    A physical quantity or simply quantity is a pr...
# 1    The International System of Units internationa...
# 2    In statistics and optimization errors and resi...
# 3    Uncertainty or Incertitude refers to epistemic...
# 4    Accuracy and precision are two measures of obs...
# ...

# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk

nltk.download('punkt')
nltk.download('wordnet')

# Function to compute stems and lemmas
def compute_stems_lemmas(content):
    porter = PorterStemmer()
    lemmatizer = WordNetLemmatizer()

    # Tokenize the content
    tokens = word_tokenize(content.lower())
    tokens = [word for word in tokens if word.isalpha()]

    # Stemming and Lemmatization
    stems = [porter.stem(token) for token in tokens]
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]

    return ' '.join(stems), ' '.join(lemmas)

# Read the previously saved corpus.csv
df = pd.read_csv('corpus.csv')

# Create empty lists to store stems and lemmas
stems_list = []
lemmas_list = []

# Iterate through each content and compute stems/lemmas
for content in df['Content']:
    stems, lemmas = compute_stems_lemmas(content)
    stems_list.append(stems)
    lemmas_list.append(lemmas)

# Add stems and lemmas to the DataFrame
df['Stems'] = stems_list
df['Lemmas'] = lemmas_list

# Create a new DataFrame with selected columns
df_tokens = df[['Topic', 'Stems', 'Lemmas']]

# Save the DataFrame to a CSV file named tokens.csv
df_tokens.to_csv('tokens.csv', index=False)

# Reset display options to default
pd.reset_option('display.max_colwidth')

# Display the DataFrame
display(df_tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                   Topic  \
# 0                     Physical quantity
# 1         International System of Units
# 2    Errors and residuals in statistics
# 3                           Uncertainty
# 4                Accuracy and precision
# ..                                  ...
# 145                               Laser
# 146                     Nuclear physics
# 147                   Mass spectrometer
# 148                           Half-life
# 149                  Radiation detector
#
#                                                  Stems  \
# 0    a physic quantiti or simpli quantiti is a prop...
# 1    the intern system of unit intern known by the ...
# 2    in statist and optim error and residu are two ...
# 3    uncertainti or incertitud refer to epistem sit...
# ...

# %%
import pandas as pd
import re
from nltk.tokenize import word_tokenize
import nltk

nltk.download('punkt')

# Read the previously saved corpus.csv
df = pd.read_csv('corpus.csv')

# Function to compute unique words (vocabulary)
def compute_unique_words(content):
    # Tokenize the content
    tokens = word_tokenize(content.lower())
    tokens = [word for word in tokens if word.isalpha()]

    # Get unique words
    unique_words = set(tokens)

    return ' '.join(unique_words)

# Create empty list to store unique words for each topic
unique_words_list = []

# Iterate through each content and compute unique words for each topic
for content in df['Content']:
    unique_words = compute_unique_words(content)
    unique_words_list.append(unique_words)

# Add unique words to the DataFrame for each topic
df['Unique Words'] = unique_words_list

# Create a new DataFrame with selected columns for topics and their corresponding unique words
df_vocabulary = df[['Topic', 'Unique Words']]

# Save the DataFrame to a CSV file named vocabulary.csv
df_vocabulary.to_csv('vocabulary.csv', index=False)

# Reset display options to default
pd.reset_option('display.max_colwidth')

# Display the DataFrame
display(df_vocabulary)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                   Topic  \
# 0                     Physical quantity
# 1         International System of Units
# 2    Errors and residuals in statistics
# 3                           Uncertainty
# 4                Accuracy and precision
# ..                                  ...
# 145                               Laser
# 146                     Nuclear physics
# 147                   Mass spectrometer
# 148                           Half-life
# 149                  Radiation detector
#
#                                           Unique Words
# 0    limited base vector si they sign vnequiv conte...
# 1    production thermometry obsolete they des techn...
# 2    likely they xnmu significance also against squ...
# 3    limited second already likely they few assigne...
# 4    si they experiment context also precision obse...
# ...

# %%
import pandas as pd
from nltk import pos_tag, word_tokenize
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Read the previously saved corpus.csv
df = pd.read_csv('corpus.csv')

# Function to compute POS tags for content
def compute_pos_tags(content):
    # Tokenize the content
    tokens = word_tokenize(content)

    # Perform POS tagging
    pos_tags = pos_tag(tokens)

    # Format pos_tags into a string for each content
    pos_tags_str = ' '.join([f"{word}/{tag}" for word, tag in pos_tags])

    return pos_tags_str

# Create empty list to store POS tags for each topic
pos_tags_list = []

# Iterate through each content and compute POS tags for each topic
for content in df['Content']:
    pos_tags = compute_pos_tags(content)
    pos_tags_list.append(pos_tags)

# Add POS tags to the DataFrame for each topic
df['Data with POS Tags'] = pos_tags_list

# Create a new DataFrame with selected columns for topics and their corresponding POS tags
df_pos = df[['Topic', 'Data with POS Tags']]

# Save the DataFrame to a CSV file named pos.csv
df_pos.to_csv('pos.csv', index=False)

# Reset display options to default
pd.reset_option('display.max_colwidth')

# Display the DataFrame
display(df_pos)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
#                                   Topic  \
# 0                     Physical quantity
# 1         International System of Units
# 2    Errors and residuals in statistics
# 3                           Uncertainty
# 4                Accuracy and precision
# ..                                  ...
# 145                               Laser
# 146                     Nuclear physics
# 147                   Mass spectrometer
# 148                           Half-life
# 149                  Radiation detector
#
#                                     Data with POS Tags
# 0    A/DT physical/JJ quantity/NN or/CC simply/RB q...
# 1    The/DT International/NNP System/NNP of/IN Unit...
# ...

# %%
# !pip install textstat
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import textstat

# Read the previously saved corpus.csv
df = pd.read_csv('corpus.csv')

# Function to compute readability using Flesch-Kincaid Grade Level
def compute_readability(content):
    # Calculate Flesch-Kincaid Grade Level
    grade_level = textstat.flesch_kincaid_grade(content)

    # Categorize readability based on the grade level
    readability = 'Easy' if grade_level <= 8 else 'Difficult'

    return readability

# Create empty list to store readability for each topic
readability_list = []

# Iterate through each content and compute readability for each topic
for content in df['Content']:
    readability = compute_readability(content)
    readability_list.append(readability)

# Add readability to the DataFrame for each topic
df['Readability'] = readability_list

# Create a new DataFrame with selected columns for topics and their corresponding readability
df_readability = df[['Topic', 'Readability']]

# Save the DataFrame to a CSV file named readability.csv
df_readability.to_csv('readability.csv', index=False)

# Reset display options to default
pd.reset_option('display.max_colwidth')

# Display the DataFrame
display(df_readability)
# Out:
#                                   Topic Readability
# 0                     Physical quantity   Difficult
# 1         International System of Units   Difficult
# 2    Errors and residuals in statistics   Difficult
# 3                           Uncertainty   Difficult
# 4                Accuracy and precision   Difficult
# ..                                  ...         ...
# 145                               Laser   Difficult
# 146                     Nuclear physics   Difficult
# 147                   Mass spectrometer   Difficult
# 148                           Half-life   Difficult
# 149                  Radiation detector   Difficult
#
# [150 rows x 2 columns]

# %%
#as by that method only difficult comes no matter what value we chose, so we assigned
#readability by this so that 'easy' and 'difficult' teo labels are there for logistic regression
import pandas as pd
import textstat

# Read the previously saved corpus.csv
df = pd.read_csv('corpus.csv')

# Function to categorize readability as 'Easy' or 'Difficult'
def categorize_readability(readability_score):
    if readability_score <= -4500:
        return 'Easy'
    else:
        return 'Difficult'

# Function to compute readability using textstat
def compute_readability(content):
    # Calculate the Flesch Reading Ease score
    readability_score = textstat.flesch_reading_ease(content)
    return readability_score

# Create empty list to store readability labels for each topic
readability_labels = []

# Iterate through each content and compute readability label for each topic
for content in df['Content']:
    readability = compute_readability(content)
    readability_label = categorize_readability(readability)
    readability_labels.append(readability_label)

# Add readability labels to the DataFrame for each topic
df['Readability'] = readability_labels

# Create a new DataFrame with 'Topic' and 'Readability'
df_readability2 = df[['Topic', 'Readability']]

# Save the DataFrame to a CSV file named readability2.csv
df_readability2.to_csv('readability2.csv', index=False)

# Display the DataFrame
display(df_readability2)
# Out:
#                                   Topic Readability
# 0                     Physical quantity   Difficult
# 1         International System of Units        Easy
# 2    Errors and residuals in statistics   Difficult
# 3                           Uncertainty   Difficult
# 4                Accuracy and precision   Difficult
# ..                                  ...         ...
# 145                               Laser        Easy
# 146                     Nuclear physics   Difficult
# 147                   Mass spectrometer        Easy
# 148                           Half-life   Difficult
# 149                  Radiation detector   Difficult
#
# [150 rows x 2 columns]

# %%
from google.colab import files
# Download the CSV files
files.download('corpus.csv')
files.download('tokens.csv')
files.download('vocabulary.csv')
files.download('readability.csv')
files.download('readability2.csv')
files.download('pos.csv')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Read the 'corpus.csv' and 'readability.csv' files
content_df = pd.read_csv('corpus.csv')
readability_df = pd.read_csv('readability2.csv')

# Merge the DataFrames based on a common column (e.g., 'Topic')
merged_df = pd.merge(content_df, readability_df, on='Topic')

# Assuming 'Content' column contains the text data and 'Readability' is the target variable
X = merged_df['Content']  # Assuming 'Content' column contains the text data
y = merged_df['Readability']  # Assuming 'Readability' is the target variable

# Initialize TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data
X_tfidf = tfidf_vectorizer.fit_transform(X)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42,stratify=y)

# Initialize the Logistic Regression model
logreg_model = LogisticRegression()

# Train the model
logreg_model.fit(X_train, y_train)

# Predict on the test set
y_pred = logreg_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Get classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7837837837837838
#               precision    recall  f1-score   support
#
#    Difficult       0.73      1.00      0.85        22
#         Easy       1.00      0.47      0.64        15
#
#     accuracy                           0.78        37
#    macro avg       0.87      0.73      0.74        37
# weighted avg       0.84      0.78      0.76        37
